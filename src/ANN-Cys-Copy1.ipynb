# %% [markdown]
# # ANN, excluding Cys-epitopes

# %%
import json
import os
from copy import deepcopy
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
# Out:
# 2025-01-15 07:36:06.327315: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-15 07:36:06.334754: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736944566.343375   92571 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736944566.345927   92571 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-15 07:36:06.354919: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import gc
# Invoke garbage collector
gc.collect()
# Out:
# 0

# %% [markdown]
# ## dataset

# %%
infile = '/home/yuan/results/epitope/epi_top_features.txt'
df = pd.read_csv(infile, sep='\t', header=0, index_col=None)
# balance the number of epitopes and non-epitopes
# shuffle rows
df = df.sample(frac=1)
df.head()
# Out:
#                          seq  label  mean_hydro_ph7  mean_hydro  mean_polar  \
# 1829448         FNFVKQGHFIGV      1       41.500000    1.073333    7.866667
# 936631       QQKMVGIDKKQDLEA      1        9.800000    0.784667    9.500000
# 2046631  LAKYICENQDSISSKLKEC      0       18.684211    0.904737    8.773684
# 1702393      FLIPPEHAHKLVFTV      0       37.933333    1.290667    7.620000
# 3109485           EPDPEPYEPI      0      -17.000000    1.377000    9.330000
#
#          mean_polar_stab  mean_VDWV  median_hydro_ph7  median_hydro  \
# 1829448         0.174917   3.666667              42.0         1.235
# 936631          0.155800   3.462000             -10.0         0.610
# 2046631         0.153053   3.404211              -5.0         1.070
# 1702393         0.177600   3.779333              41.0         1.320
# 3109485         0.156600   3.547000             -38.5         1.915
#
#          median_polar  ...  has_C  has_I  has_L  has_K  has_F  has_P  has_S  \
# 1829448          7.45  ...      0      1      0      1      1      0      0
# 936631          10.50  ...      0      1      1      1      0      0      0
# 2046631          9.20  ...      1      1      1      1      0      0      1
# 1702393          8.00  ...      0      1      1      1      1      1      0
# 3109485          8.00  ...      0      1      0      0      0      1      0
#
#          has_T  has_Y  has_V
# 1829448      0      0      1
# 936631       0      0      1
# 2046631      0      1      0
# 1702393      1      0      1
# 3109485      0      1      0
#
# [5 rows x 50 columns]

# %%
# %load_ext autoreload
# %autoreload 2

from seq.my_ann import MyAnn
from seq.compare_model import CompareModel

# %% [markdown]
# ## filter I: without Cys

# %%
# keep epitopes without Cys
feature = 'has_C'
print('entire data:', df.shape)
print('epitopes without Cys:', df[(df[feature]==0) & (df['label']==1)].shape)
print('epitopes having Cys:', df[(df[feature]==1) & (df['label']==1)].shape)
sub_df = df[~(df[feature]==1)].drop([feature], axis=1)
print('filtered data:', sub_df.shape)
# Out:
# entire data: (3458238, 50)
# epitopes without Cys: (1639058, 50)
# epitopes having Cys: (226184, 50)
# filtered data: (2891465, 49)

# %%
# prepare 
c = MyAnn()
c.get_xy(sub_df)
# Out:
# X: (2891465, 47) float16
# y: (2891465,) float16
# labels: Counter({np.float16(1.0): 1639058, np.float16(0.0): 1252407})
# train data: (1619220, 47) (1619220,)
# validate data: (693952, 47) (693952,)
# test data (578293, 47) (578293,)

# %%
# train model
c.declare_model()
c.train(epochs=10)
# Out:
# I0000 00:00:1736944693.688411   92571 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1187 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │        24,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 96)             │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            97 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,921 (288.75 KB)
#  Trainable params: 73,921 (288.75 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736944695.173966   92792 service.cc:148] XLA service 0x7f7260004bf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1736944695.173990   92792 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-01-15 07:38:15.205028: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1736944695.289196   92792 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   181/50601 ━━━━━━━━━━━━━━━━━━━━ 42s 837us/step - accuracy: 0.5986 - auc: 0.6162 - loss: 0.6686 - mse: 0.2372 - precision: 0.6268 - recall: 0.7411
# I0000 00:00:1736944695.854098   92792 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 50601/50601 ━━━━━━━━━━━━━━━━━━━━ 94s 2ms/step - accuracy: 0.6582 - auc: 0.7029 - loss: 0.6205 - mse: 0.2153 - precision: 0.6651 - recall: 0.8008 - val_accuracy: 0.6800 - val_auc: 0.7342 - val_loss: 0.5983 - val_mse: 0.2055 - val_precision: 0.6778 - val_recall: 0.8292
# Epoch 2/10
# 50601/50601 ━━━━━━━━━━━━━━━━━━━━ 83s 2ms/step - accuracy: 0.6792 - auc: 0.7311 - loss: 0.6006 - mse: 0.2063 - precision: 0.6818 - recall: 0.8149 - val_accuracy: 0.6898 - val_auc: 0.7452 - val_loss: 0.5879 - val_mse: 0.2011 - val_precision: 0.6889 - val_recall: 0.8248
# Epoch 3/10
# 50601/50601 ━━━━━━━━━━━━━━━━━━━━ 81s 2ms/step - accuracy: 0.6865 - auc: 0.7394 - loss: 0.5943 - mse: 0.2035 - precision: 0.6902 - recall: 0.8103 - val_accuracy: 0.6919 - val_auc: 0.7486 - val_loss: 0.5876 - val_mse: 0.2009 - val_precision: 0.6890 - val_recall: 0.8311
# Epoch 4/10
# 50601/50601 ━━━━━━━━━━━━━━━━━━━━ 76s 1ms/step - accuracy: 0.6887 - auc: 0.7429 - loss: 0.5910 - mse: 0.2021 - precision: 0.6936 - recall: 0.8090 - val_accuracy: 0.6945 - val_auc: 0.7504 - val_loss: 0.5833 - val_mse: 0.1990 - val_precision: 0.7004 - val_recall: 0.8051
# Epoch 5/10
# 50601/50601 ━━━━━━━━━━━━━━━━━━━━ 92s 2ms/step - accuracy: 0.6904 - auc: 0.7449 - loss: 0.5895 - mse: 0.2014 - precision: 0.6954 - recall: 0.8085 - val_accuracy: 0.6968 - val_auc: 0.7540 - val_loss: 0.5809 - val_mse: 0.1981 - val_precision: 0.7014 - val_recall: 0.8091
# Epoch 6/10
# 50601/50601 ━━━━━━━━━━━━━━━━━━━━ 75s 1ms/step - accuracy: 0.6911 - auc: 0.7462 - loss: 0.5887 - mse: 0.2010 - precision: 0.6967 - recall: 0.8060 - val_accuracy: 0.6898 - val_auc: 0.7538 - val_loss: 0.5851 - val_mse: 0.2001 - val_precision: 0.6751 - val_recall: 0.8721
# Epoch 7/10
# 50601/50601 ━━━━━━━━━━━━━━━━━━━━ 79s 2ms/step - accuracy: 0.6920 - auc: 0.7474 - loss: 0.5874 - mse: 0.2005 - precision: 0.6974 - recall: 0.8075 - val_accuracy: 0.6953 - val_auc: 0.7549 - val_loss: 0.5809 - val_mse: 0.1981 - val_precision: 0.6896 - val_recall: 0.8404
# Epoch 8/10
# 50601/50601 ━━━━━━━━━━━━━━━━━━━━ 84s 2ms/step - accuracy: 0.6931 - auc: 0.7486 - loss: 0.5865 - mse: 0.2001 - precision: 0.6989 - recall: 0.8064 - val_accuracy: 0.6985 - val_auc: 0.7566 - val_loss: 0.5789 - val_mse: 0.1972 - val_precision: 0.7053 - val_recall: 0.8033
# Epoch 9/10
# 50601/50601 ━━━━━━━━━━━━━━━━━━━━ 92s 2ms/step - accuracy: 0.6929 - auc: 0.7485 - loss: 0.5867 - mse: 0.2002 - precision: 0.6985 - recall: 0.8063 - val_accuracy: 0.6964 - val_auc: 0.7566 - val_loss: 0.5791 - val_mse: 0.1973 - val_precision: 0.6908 - val_recall: 0.8398
# Epoch 10/10
# 50601/50601 ━━━━━━━━━━━━━━━━━━━━ 77s 2ms/step - accuracy: 0.6939 - auc: 0.7491 - loss: 0.5860 - mse: 0.1999 - precision: 0.6993 - recall: 0.8074 - val_accuracy: 0.6980 - val_auc: 0.7558 - val_loss: 0.5786 - val_mse: 0.1971 - val_precision: 0.6986 - val_recall: 0.8209
#    accuracy       auc      loss       mse  precision    recall  val_accuracy  \
# 0  0.665533  0.713180  0.613822  0.212214   0.669879  0.809222      0.680018
# 1  0.681323  0.733135  0.599045  0.205599   0.684026  0.814515      0.689832
# 2  0.686761  0.739994  0.593606  0.203187   0.690935  0.810316      0.691866
#
#     val_auc  val_loss   val_mse  val_precision  val_recall
# 0  0.734243  0.598337  0.205473       0.677818    0.829185
# 1  0.745172  0.587892  0.201062       0.688945    0.824753
# 2  0.748613  0.587620  0.200862       0.689015    0.831078
#    accuracy       auc      loss       mse  precision    recall  val_accuracy  \
# 0  0.665533  0.713180  0.613822  0.212214   0.669879  0.809222      0.680018
# 1  0.681323  0.733135  0.599045  0.205599   0.684026  0.814515      0.689832
# 2  0.686761  0.739994  0.593606  0.203187   0.690935  0.810316      0.691866
# 3  0.688997  0.743079  0.591023  0.202094   0.693816  0.808653      0.694542
# 4  0.690271  0.744847  0.589632  0.201464   0.695509  0.807602      0.696795
# 5  0.691075  0.746159  0.588432  0.200961   0.696795  0.806317      0.689801
# 6  0.692019  0.747236  0.587696  0.200598   0.697515  0.807145      0.695300
# 7  0.692454  0.747865  0.587139  0.200349   0.698223  0.806432      0.698482
# 8  0.692782  0.748256  0.586792  0.200226   0.698442  0.806811      0.696382
# 9  0.693215  0.748759  0.586445  0.200049   0.699184  0.805996      0.697992
#
#     val_auc  val_loss   val_mse  val_precision  val_recall
# 0  0.734243  0.598337  0.205473       0.677818    0.829185
# 1  0.745172  0.587892  0.201062       0.688945    0.824753
# 2  0.748613  0.587620  0.200862       0.689015    0.831078
# 3  0.750429  0.583337  0.198967       0.700406    0.805056
# 4  0.754002  0.580915  0.198051       0.701416    0.809099
# 5  0.753798  0.585139  0.200079       0.675073    0.872078
# 6  0.754903  0.580885  0.198144       0.689561    0.840369
# 7  0.756603  0.578919  0.197199       0.705311    0.803272
# 8  0.756556  0.579082  0.197345       0.690833    0.839766
# 9  0.755763  0.578617  0.197076       0.698615    0.820949

# %%
# evaluate model
c.plot_acc_recall()

# %%
# evaluate model using test data
c.test()
c.plot_prob()
c.plot_roc()
# Out:
# 18072/18072 ━━━━━━━━━━━━━━━━━━━━ 20s 1ms/step - accuracy: 0.6981 - auc: 0.7559 - loss: 0.5787 - mse: 0.1971 - precision: 0.6985 - recall: 0.8219
# {'accuracy': 0.6985421180725098, 'auc': 0.7561813592910767, 'loss': 0.5785055160522461, 'mse': 0.19702164828777313, 'precision': 0.698725700378418, 'recall': 0.8219546675682068}
# 18072/18072 ━━━━━━━━━━━━━━━━━━━━ 7s 354us/step
# [[0.74722797]
#  [0.23254706]
#  [0.8212573 ]]

# %%
# save entire model
c.save_model('../models/epitopes_ann_notCys_drop.keras')
# Out:
# <Sequential name=sequential_1, built=True>

# %% [markdown]
# ## filter II: having Cys

# %%
# keep epitopes container Cys
feature = 'has_C'
print('entire data:', df.shape)
print('epitopes without Cys:', df[(df[feature]==0) & (df['label']==1)].shape)
print('epitopes having Cys:', df[(df[feature]==1) & (df['label']==1)].shape)
sub_df = df[~(df[feature]==0)].drop([feature], axis=1)
print('filtered data:', sub_df.shape)
# Out:
# entire data: (3458238, 50)
# epitopes without Cys: (1639058, 50)
# epitopes having Cys: (226184, 50)
# filtered data: (566773, 49)

# %%
# prepare 
c = MyAnn()
c.get_xy(sub_df)
# Out:
# X: (566773, 47) float16
# y: (566773,) float16
# labels: Counter({np.float16(0.0): 340589, np.float16(1.0): 226184})
# train data: (317392, 47) (317392,)
# validate data: (136026, 47) (136026,)
# test data (113355, 47) (113355,)

# %%
# train model
c.declare_model()
c.train(epochs=10)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 512)            │        24,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 96)             │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            97 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,921 (288.75 KB)
#  Trainable params: 73,921 (288.75 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/10
# 9919/9919 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.7084 - auc: 0.7536 - loss: 0.5756 - mse: 0.1951 - precision: 0.6448 - recall: 0.6005 - val_accuracy: 0.7396 - val_auc: 0.7921 - val_loss: 0.5369 - val_mse: 0.1794 - val_precision: 0.6631 - val_recall: 0.7074
# Epoch 2/10
# 9919/9919 ━━━━━━━━━━━━━━━━━━━━ 15s 1ms/step - accuracy: 0.7367 - auc: 0.7878 - loss: 0.5423 - mse: 0.1811 - precision: 0.6585 - recall: 0.7063 - val_accuracy: 0.7424 - val_auc: 0.7990 - val_loss: 0.5297 - val_mse: 0.1764 - val_precision: 0.6614 - val_recall: 0.7269
# Epoch 3/10
# 9919/9919 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - accuracy: 0.7402 - auc: 0.7934 - loss: 0.5365 - mse: 0.1787 - precision: 0.6592 - recall: 0.7242 - val_accuracy: 0.7445 - val_auc: 0.8018 - val_loss: 0.5263 - val_mse: 0.1751 - val_precision: 0.6623 - val_recall: 0.7346
# Epoch 4/10
# 9919/9919 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.7427 - auc: 0.7971 - loss: 0.5324 - mse: 0.1770 - precision: 0.6591 - recall: 0.7297 - val_accuracy: 0.7482 - val_auc: 0.8067 - val_loss: 0.5215 - val_mse: 0.1734 - val_precision: 0.6640 - val_recall: 0.7476
# Epoch 5/10
# 9919/9919 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - accuracy: 0.7434 - auc: 0.7983 - loss: 0.5311 - mse: 0.1766 - precision: 0.6592 - recall: 0.7394 - val_accuracy: 0.7471 - val_auc: 0.8053 - val_loss: 0.5230 - val_mse: 0.1736 - val_precision: 0.6610 - val_recall: 0.7527
# Epoch 6/10
# 9919/9919 ━━━━━━━━━━━━━━━━━━━━ 18s 2ms/step - accuracy: 0.7450 - auc: 0.8005 - loss: 0.5292 - mse: 0.1758 - precision: 0.6627 - recall: 0.7431 - val_accuracy: 0.7481 - val_auc: 0.8080 - val_loss: 0.5224 - val_mse: 0.1734 - val_precision: 0.6599 - val_recall: 0.7618
# Epoch 7/10
# 9919/9919 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.7451 - auc: 0.8011 - loss: 0.5284 - mse: 0.1755 - precision: 0.6617 - recall: 0.7412 - val_accuracy: 0.7508 - val_auc: 0.8090 - val_loss: 0.5187 - val_mse: 0.1721 - val_precision: 0.6598 - val_recall: 0.7758
# Epoch 8/10
# 9919/9919 ━━━━━━━━━━━━━━━━━━━━ 14s 1ms/step - accuracy: 0.7489 - auc: 0.8057 - loss: 0.5234 - mse: 0.1735 - precision: 0.6654 - recall: 0.7482 - val_accuracy: 0.7511 - val_auc: 0.8109 - val_loss: 0.5157 - val_mse: 0.1711 - val_precision: 0.6624 - val_recall: 0.7679
# Epoch 9/10
# 9919/9919 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.7500 - auc: 0.8048 - loss: 0.5234 - mse: 0.1734 - precision: 0.6638 - recall: 0.7521 - val_accuracy: 0.7519 - val_auc: 0.8127 - val_loss: 0.5146 - val_mse: 0.1706 - val_precision: 0.6634 - val_recall: 0.7688
# Epoch 10/10
# 9919/9919 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - accuracy: 0.7499 - auc: 0.8066 - loss: 0.5218 - mse: 0.1730 - precision: 0.6669 - recall: 0.7505 - val_accuracy: 0.7522 - val_auc: 0.8132 - val_loss: 0.5144 - val_mse: 0.1706 - val_precision: 0.6637 - val_recall: 0.7691
#    accuracy       auc      loss       mse  precision    recall  val_accuracy  \
# 0  0.723087  0.771201  0.559667  0.188369   0.654003  0.650607      0.739623
# 1  0.736988  0.788680  0.541583  0.180805   0.658377  0.709242      0.742380
# 2  0.740718  0.794060  0.535805  0.178450   0.659546  0.724607      0.744453
#
#     val_auc  val_loss   val_mse  val_precision  val_recall
# 0  0.792074  0.536875  0.179350       0.663054    0.707392
# 1  0.798958  0.529706  0.176434       0.661429    0.726908
# 2  0.801751  0.526325  0.175100       0.662295    0.734567
#    accuracy       auc      loss       mse  precision    recall  val_accuracy  \
# 0  0.723087  0.771201  0.559667  0.188369   0.654003  0.650607      0.739623
# 1  0.736988  0.788680  0.541583  0.180805   0.658377  0.709242      0.742380
# 2  0.740718  0.794060  0.535805  0.178450   0.659546  0.724607      0.744453
# 3  0.742794  0.797429  0.532339  0.177000   0.660104  0.733414      0.748173
# 4  0.744987  0.799870  0.529541  0.175884   0.661283  0.740611      0.747115
# 5  0.745806  0.801384  0.527769  0.175196   0.662058  0.742126      0.748092
# 6  0.747111  0.803284  0.525855  0.174512   0.663483  0.743870      0.750761
# 7  0.748034  0.803963  0.524917  0.174089   0.664019  0.746719      0.751092
# 8  0.749272  0.805310  0.523585  0.173477   0.664922  0.749892      0.751900
# 9  0.749584  0.806075  0.522535  0.173176   0.665476  0.749576      0.752187
#
#     val_auc  val_loss   val_mse  val_precision  val_recall
# 0  0.792074  0.536875  0.179350       0.663054    0.707392
# 1  0.798958  0.529706  0.176434       0.661429    0.726908
# 2  0.801751  0.526325  0.175100       0.662295    0.734567
# 3  0.806721  0.521462  0.173363       0.664023    0.747584
# 4  0.805287  0.523009  0.173607       0.660997    0.752720
# 5  0.807965  0.522417  0.173426       0.659868    0.761797
# 6  0.809002  0.518690  0.172051       0.659803    0.775826
# 7  0.810892  0.515721  0.171061       0.662447    0.767946
# 8  0.812723  0.514567  0.170574       0.663362    0.768812
# 9  0.813150  0.514388  0.170608       0.663706    0.769051

# %%
# evaluate model
c.plot_acc_recall()

# %%
# evaluate model using test data
c.test()
c.plot_prob()
c.plot_roc()
# Out:
# 3543/3543 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.7499 - auc: 0.8113 - loss: 0.5166 - mse: 0.1715 - precision: 0.6602 - recall: 0.7686
# {'accuracy': 0.7508094310760498, 'auc': 0.8128573298454285, 'loss': 0.5144199728965759, 'mse': 0.1706424206495285, 'precision': 0.6606358885765076, 'recall': 0.7698884010314941}
# 3543/3543 ━━━━━━━━━━━━━━━━━━━━ 2s 449us/step
# [[0.08773661]
#  [0.24357344]
#  [0.35324994]]

# %%
# save entire model
c.save_model('../models/epitopes_ann_hasCys.keras')
# Out:
# <Sequential name=sequential_2, built=True>

# %% [markdown]
# ## compare

# %%
model1 = tf.keras.models.load_model('../models/epitopes_ann_hasCys.keras')
model2 = tf.keras.models.load_model('../models/epitopes_ann_notCys.keras')

# %%
from seq.compare_model import CompareModel
cm = CompareModel(model1, model2)
cm.predict(df)
# Out:
# X: (3458238, 48) float16
# y: (3458238,) float16
# labels: Counter({np.float16(1.0): 1865242, np.float16(0.0): 1592996})
# 108070/108070 ━━━━━━━━━━━━━━━━━━━━ 51s 469us/step
# 108070/108070 ━━━━━━━━━━━━━━━━━━━━ 46s 427us/step

# %%
cm.plot_roc('hasCys', 'notCys')
